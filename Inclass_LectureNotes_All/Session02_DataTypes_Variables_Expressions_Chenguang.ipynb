# %% [markdown]
# # HUDM5001 Programming for Data Science Session 02
# ## Python Intro: Data Types, Variables & Expressions
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cgpan/hudm5001/blob/main/Week_02/02_DataTypes_Variables_Expressions.ipynb)
#
# [**Chenguang Pan**](https://cpan.ai/), [**Youmi Lab**](https://youmilab.ai/)
# **Teachers College, Columbia University**
#
# About this notebook:
# This notebook is adapted from Prof. Youmi Suk's materials for HUDM 5001, Programming for Data Science ([original repository](https://github.com/youmilab/hudm5001)).
# Wording in this notebook was refined with Claude. I am responsible for its accuracy.

# %% [markdown]
# ---
# ## 0. Big Picture
#
# ### 0.1 Learning Objectives
# By the end of this session you will be able to:
# - Create variables following Python's **naming rules**, and inspect them with `type()`.
# - Use the core **scalar** types: `bool`, `int`, `float`, `str`.
# - Use the core **container** types: `list`, `tuple`, `set`, `dict`, and `range`.
# - Distinguish **mutable** vs **immutable** types and explain why it matters.
# - Index, slice, and loop over strings and lists; format strings with f-strings and `.format()`.
# - Convert between types and predict when a conversion will fail.
#
# ### 0.2 Key Concepts
# `variable`  `expression`  `bool`  `int`  `float`  `str`  `list`  `tuple`  `set`  `dict`  `range`  `mutable`  `immutable`  `indexing`  `slicing`
#
# ### 0.3 Today's Agenda
# 1. Review Google Colab and Markdown syntax
# 2. Variables & expressions: naming, assignment, `type()`
# 3. Booleans and numbers (int, float)
# 4. Strings: indexing, slicing, methods, formatting
# 5. Containers: list, tuple, set, dict
# 6. Ranges and type conversions

# %% [markdown]
# ---
# ## ▶️ Setup — run this cell first

# %%
# === SETUP — run me first! ===
# Pure-Python session — only the standard library.
import sys
print('Python', sys.version.split()[0])
# Out:
# Python 3.13.15

# %% [markdown]
# ## 1.0 Python Introduction
#
# **Python** is one of the most widely used programming languages in the world, famous for its clean, readable syntax and a vast ecosystem of free, community-built libraries. First released by Guido van Rossum in 1991, it is a **general-purpose** language: the same skills you learn here carry over to data analysis, automation, web development, scientific computing, and artificial intelligence.
#
# **Why Python for this course?**
# - **Readable** — code reads almost like plain English, so you can focus on the *data*, not the syntax.
# - **Free & open-source** — no license fees (unlike SPSS, SAS, or Stata).
# - **Batteries included** — a rich standard library, plus hundreds of thousands of add-on packages on [PyPI](https://pypi.org/).
# - **Runs everywhere** — Windows, macOS, Linux, and the cloud (like this Colab notebook).
# - **In demand** — consistently ranked the #1 language for data science and one of the most sought-after job skills.
#
# ### 1.1 Python for Data Science
# Python can do almost everything the other widely-used statistical software packages can do — and usually more:
#
# <p align="left">
#   <img src="https://raw.githubusercontent.com/cgpan/hudm5001/main/figures/r_logo.png" width="150">
#   <img src="https://raw.githubusercontent.com/cgpan/hudm5001/main/figures/sas_logo.png"  width="150">
#   <img src="https://raw.githubusercontent.com/cgpan/hudm5001/main/figures/spss_logo.png" width="150">
#   <img src="https://raw.githubusercontent.com/cgpan/hudm5001/main/figures/stata_logo.png" width="150">
# </p>
#
# The entire data-science workflow is supported by a mature stack of libraries:
#
# | Library | What it's for |
# |---|---|
# | `NumPy` | Fast numerical arrays and linear algebra |
# | `pandas` | Spreadsheet-like data tables (*DataFrames*) for cleaning & wrangling |
# | `matplotlib` / `seaborn` / `plotly` | Data visualization |
# | `statsmodels` | Classical statistics — regression, ANOVA, time series |
# | `scikit-learn` | Machine learning, all in one place |
#
# With these tools, Python can run nearly every Machine Learning algorithm you'll encounter, including but not limited to:
# `Generalized Linear Regression`, `Random Forest`, `Support Vector Machine`, `XGBoost`, and `Neural Networks` — up to more advanced models such as `Generative Adversarial Networks (GANs)`, `Reinforcement Learning`, `Transformers`, and `Diffusion Models`.

# %% [markdown]
# ---
# ## 2. Content
#
# ### 2.1 Variables & expressions
# A **variable** is a name that refers to a value. You create one with the assignment operator `=`.
# Variable names can be any length but must **start with a letter or underscore**, followed by letters, numbers,
# or underscores and can't be a reserved keyword.

# %%
# valid assignments    <---- a sentence starting with a hash tag is a comment and is never executed.
x = 5               # define an variable just like what we once learn in Math class
print(x)
# Out:
# 5

# %%
# multiple assignment at once
x = y = z = 5         # all three get 5
print(x, y, z)
# Out:
# 5 5 5

# %%
a, b = 3, 4           # 'unpacking': a=3, b=4
print(a, b)
# Out:
# 3 4

# %%
# use an underscore as thousands separator 1,000,000
my_wealth = 1_000_000
print(my_wealth)
# Out:
# 1000000

# %%
# These are INVALID
# 1_model = 2     # can't start with a digit
# return = 3      # 'return' is a reserved keyword

# %% [markdown]
# Let's do some basic math operations. We will learn complex math operations next week.

# %%
# addition/ plus. Name the variable as a_plus_b
a_plus_b = a + b
print(a_plus_b)
# Out:
# 7

# %%
# subtaction/ minus. Name the variable as a_minus_b

# %%
# multiplication/ times. Name the variable as a_times_b
a_times_b = a * b
a_times_b
# Out:
# 12

# %%
# division/ divided by. Name the variable as a_over_b

# %%
# exponentiation
a_quad = a**2
a_cube = a**3
print(a_quad, a_cube)
# Out:
# 9 27

# %% [markdown]
# We will introduce more advanced calculations in the future.

# %% [markdown]
# #### ✏️ Exercise 1- Your turn
# John's GPA is 3.15, while Jane's GPA is 3.85. Write down the Python code to get the average GPA of John and Jane.

# %%
# Your code here
john_gpa=3.15
jane_gpa=3.85
mean_gpa=(john_gpa + jane_gpa)/2
print(mean_gpa)

JohnGPA = 3.15
# Out:
# 3.5

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# ```python
# John_GPA = 3.15
# Jane_GPA = 3.85
# GPA_mean = (John_GPA + Jane_GPA)/2
# print(GPA_mean)
# ```
#
# </details>

# %% [markdown]
# > **Kind Reminders:**
# - You must give a meaningful variable name for readability.
# - Always add comments to the key line of code. The future you will be appreciated to the current you! Trust me!

# %% [markdown]
# Variables can be defined not only in numbers, but also in strings (i.e., text/ characters). You must use quote or double quote to tell python this is an string.

# %%
name = 'John'
gender = "male"
age = 16
age_ = "16"
print(name, gender, age, age_)
# Out:
# John male 16 16

# %%
age, age_ = 16, "16"
print(type(age), type(age_))
# Out:
# <class 'int'> <class 'str'>

# %%
print(type(age_))
# Out:
# <class 'str'>

# %% [markdown]
# #### ✏️ Exercise 2
# What is the result of the code below? Just think. No need to run.

# %% [markdown]
# ```python
# John_age = "16"
# Jane_age = "15"
#
# John_Jane = John_age + Jane_age
# print(John_Jane)
# ```

# %%
John_age = "=="

a_fancy_result = John_age * 10
print(a_fancy_result)

# %% [markdown]
# `type()` reports a value's data type. Use `del` to delete a variable.

# %%
print(type(age))
print(type(age_))
# Out:
# <class 'int'>
# <class 'str'>

# %%
del age_        # remove the variable
# print(age_)    # would now raise NameError

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 3
# Please select the incorrect variable name(s):
# A. `aws`
# B. `aws-instance`
# C. `_aws_instance`
# D. `3rd_instance`.

# %% [markdown]
# <details>
# <summary>▶ Show solution</summary>
#
# # aws            -> valid
# # aws-instance   -> INVALID (hyphen not allowed)
# # _aws_instance  -> valid (underscore start is fine)
# # 3rd_instance   -> INVALID (starts with a digit)
#
# </details>

# %% [markdown]
# ### 2.2 Booleans
# A **boolean** is either `True` or `False`. Booleans power every decision your code makes. Check a value's type
# with `isinstance(value, type)`.

# %%
exam_pass = True

# %%
True + False
# Out:
# 1

# %%
print(isinstance(exam_pass, int))   # True
# Out:
# True

# %% [markdown]
# Compound conditions use `and`, `or`, `not`. Python **short-circuits**: in `A and B`, if `A`
# is `False`, `B` is never evaluated.

# %%
exam_pass = True
graduation = False

print(exam_pass and graduation)
# Out:
# False

# %%
print(exam_pass or graduation)
# Out:
# True

# %%
print(not exam_pass)
print(not graduation)
# Out:
# False
# True

# %% [markdown]
# ### 2.3 Numbers: `int` and `float`
# - **`int`** — whole numbers (`21`, `-4`, `1000000`).
# - **`float`** — numbers with a decimal point (`0.95`, `-3.14`).

# %%
epoch = 21
pi = 3.1415926
print(epoch, type(epoch))
print(pi, type(pi))
print('is epoch an int? ', isinstance(epoch, int))
print('is pi a float?   ', isinstance(pi, float))
# Out:
# 21 <class 'int'>
# 3.1415926 <class 'float'>
# is epoch an int?  True
# is pi a float?    True

# %%
# Out:
# This is a test for  3.100

# %%
# round the demcimal to certain digit: round(a_float, ndigits)
pi_rounded = round(pi, 3)
print(pi_rounded)
# Out:
# 3.142

# %% [markdown]
# ### 2.4 Strings
# A **string** (`str`) is text — a sequence of characters in single or double quotes. Strings are **indexable**
# (0-based) and **sliceable**, but **immutable** (you can't change a character in place).

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/cgpan/hudm5001/main/figures/string_slice.png" width="700">
# </p>

# %%
a_string = "Python"
first_letter = a_string[2]
print(first_letter)
print(a_string[4], a_string[-2])
# Out:
# t
# o o

# %%
a_string[0 : 3]  # start at a, end before b
# Out:
# 'Pyt'

# %%
status = 'success'
print(type(status))
print('first char :', status[0])      # 's'
print('first two  :', status[:2])     # 'su'
print('last two   :', status[-2:])    # 'ss'
print('length     :', len(status))    # using len() to show the total length
# Out:
# <class 'str'>
# first char : s
# first two  : su
# last two   : ss
# length     : 7

# %%
# Handy string methods
print(status.upper())           #
print(status.upper().lower())   # You can attach two or more functions, but it is rare.
print(status.startswith('a'))   # False
print(status.endswith('s'))     # True
print('  trim me  '.strip())    # remove surrounding whitespace
# Out:
# SUCCESS
# success
# False
# True
# trim me

# %%
print('Better call Saul'.split())
# Out:
# ['Better', 'call', 'Saul']

# %% [markdown]
# **Immutability** — this fails because strings can't be edited in place:

# %%
status = 'success'
#status[0] = 'X'        # TypeError: 'str' object does not support item assignment
status = 'Xuccess'        # but REASSIGNING the whole variable is fine
print(status)
# Out:
# Xuccess

# %% [markdown]
# But people say: I can use other trick to change the string. Why does it work?
# The `.replace()` does not change the original string, but create a brand new one.

# %%
status_2 = status.replace("s", "y")
status_2
# Out:
# 'yucceyy'

# %% [markdown]
# **Building strings.** Concatenate with `+`, or (better) insert values with **f-strings** or
# `.format()`.

# %%
root_path = '/Users/ys2952/repo/hudm5001/'
file = 'iris.csv'
print(root_path + file)                       # concatenation

epoch, loss = 3, 0.12
print(f'Epoch: {epoch}, loss: {loss}')                 # f-string (modern, preferred)
print('Epoch: {}, loss: {}'.format(epoch, loss))       # .format() (also common)
# Out:
# /Users/ys2952/repo/hudm5001/iris.csv
# Epoch: 3, loss: 0.12
# Epoch: 3, loss: 0.12

# %%
print("Better call Saul")
name_ = "Pinkman"
print(f"Better call {name_}")
# Out:
# Better call Saul
# Better call Pinkman

# %%
name_ = "Heisenberg"
print(f"Say my name {name_}.")
print("Say my name {}".format(name_))
# Out:
# Say my name Heisenberg.
# Say my name Heisenberg

# %%
epoch, loss = 3, 0.12


print(f'Epoch: {epoch}, loss: {loss}')                 # f-string (modern, preferred)
print('Epoch: {}, loss: {}'.format(epoch, loss))       # .format

# %% [markdown]
# Now, let's try a longer string.

# %%
long_str, name = "You know nothing, ", "Jon Snow."
combined = long_str + name

# %% [markdown]
# ### Last Week
# We learned:
# > - How to define a variable correctly.
# > - The data types, such as `int`, `float`, `bool`, `string`.
# > - Basic operations on a string: index, slice, strip, replace, and f-format
# > - Other functions like `len()`, `.upper()`, `.lower()`

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 3
# Define a variable to load the string "May the force be with you." Print
# (a) the string in UPPERCASE,
# (b) its first 3 characters,
# (c) get the length of this sentence, using the `len()` function,
# (d) print a conclusion using `f-strings` or `.format()`: The length of this string is ___.

# %%
# Your code here
# (a) upper case
a_str = "May the force be with you."
a_str_up = a_str.upper()
print(a_str_up)

# (b) first 3 chars
fisrt_char3 = a_str[0:3]
print(fisrt_char3)

# (c) get the length
len_str = len(a_str)
print(len_str)

# f-strings
print(f"The length of this string is {len_str}.")
print("The length of this string is {}.".format(len_str))
# A quick review of last week
# strip, replace, split
a_str = "I am Iron Man."
a_str_strip = a_str.strip("-")
print(a_str_strip)

a_str2 = a_str.replace("Iron", "Bat")
print(a_str2)

a_str_lst = a_str.split()
print(a_str_lst)

# test whether a string is in the current string
"Iron" not in a_str
# Out:
# MAY THE FORCE BE WITH YOU.
# May
# 26
# The length of this string is 26.
# The length of this string is 26.
# I am Iron Man.
# I am Bat Man.
# ['I', 'am', 'Iron', 'Man.']
# False

# %% [markdown]
# To ensure we are on the same page, I summarize the names of notations as below:
# | Symbol | Technical / Formal Name | Common / Informal Name |
# | :---: | :--- | :--- |
# | `[` | Square bracket | Bracket |
# | `{` | Curly brace / bracket | Big bracket |
# | `(` | Parenthesis / Round bracket | Parenthesis |
# | `-` | Hyphen / Dash | Dash |
# | `_` | Underscore | Underscore |
# | `` ` `` | Backtick / Grave accent | Backtick |
# |`#` | Hashtag / Hash |  Hashtag/ Num. |
# |`/` | Forward slash |  Forward slash |
# |`\` | Back slash |  Back slash |
# |`*` | asterisk |  Star |

# %% [markdown]
# ### 2.5 Lists — the workhorse container
# A **list** is an *ordered, mutable* collection written in `[ ]`. It can hold mixed types, be indexed and
# sliced, grown, and looped over.

# %% [markdown]
# <p align="left">
#   <img src="https://raw.githubusercontent.com/cgpan/hudm5001/main/figures/list_slice.png" width="700">
# </p>
#
# *Image Source:* [scientecheasy](https://www.scientecheasy.com/2023/03/python-slice-list.html/#google_vignette)

# %%
financial_derivatives = ['futures', 'swaps', 'options']
print(type(financial_derivatives))
print('first:', financial_derivatives[0])
print('first 3 chars of first item:', financial_derivatives[0][:3])

# you can count the number of elements in the list
deri_count = len(financial_derivatives)
print('The number of the current finanacial derivatives is {}'.format(deri_count))

# lists are MUTABLE: .change, .append, .extend
financial_derivatives[1] = 'forwards'      # change an element
print(financial_derivatives)
# Out:
# <class 'list'>
# first: futures
# first 3 chars of first item: fut
# The number of the current finanacial derivatives is 3
# ['futures', 'forwards', 'options']

# %%
financial_derivatives.append('bonds')      # add to the end
print(financial_derivatives)
# Out:
# ['futures', 'forwards', 'options', 'bonds']

# %% [markdown]
# Note: the `.append()` and `.extend()` are different:
# - `.append()` adds the whole content you provide as one single element;
# - `.extend()` iterates over the object you provide and adds each element seperately.

# %%
names = ['Saul Goodman', 'Walter White']
names.append("Gus Fring")
print(names)

names.extend(["Jesse Pinkman2"])
names
# Out:
# ['Saul Goodman', 'Walter White', 'Gus Fring']
# ['Saul Goodman', 'Walter White', 'Gus Fring', 'Jesse Pinkman2']

# %%
# string can be converted into list --> using .split()
got = "You know nothing, Jon Snow."
# split the string based on the space
got_vocab = got.split()
print(got_vocab)
# Out:
# ['You', 'know', 'nothing,', 'Jon', 'Snow.']

# %%
# split the string based on the punctuation like comma or period
got_split = got.split(",")
print(got_split)
# Out:
# ['You know nothing', ' Jon Snow.']

# %%
# Lists can be concatenated with +
variables = ['x1', 'x1', 'x2'] + ['x3', 'x4']
print(variables)
# Out:
# ['x1', 'x1', 'x2', 'x3', 'x4']

# %%
# you can remove the first unit it finds, keep the rest untouched.
variables.remove("x1")
print(variables)
# Out:
# ['x1', 'x2', 'x3', 'x4']

# %%
# You can sort your list
num_list = [5,2,7,4,9]
num_list.sort()
print("In increasing order: ", num_list)

num_list.sort(reverse=True)
print("In decreasing oder: ", num_list)

# You can also sort a list alphabetically
names = ["John", "Zack", "Jack", "Alice"]
names.sort()
print(names)
# Out:
# In increasing order:  [2, 4, 5, 7, 9]
# In decreasing oder:  [9, 7, 5, 4, 2]
# ['Alice', 'Jack', 'John', 'Zack']

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 4 - Foundations for NLP/Computational linguistic
# Challenge: ★★★★☆
# There is a student's writting sample. Please do:
# 1. using `.split()` function to spit the text into list of words.
# 2. get the length of this list, name this original length as `len_original`.
# 3. For the same original draft, remove all the basic words (a.k.a., stop words in NLP) from this draft. Suppose the basic words here are "is" and "and". Please use `.replace()` function. See tips.
# 4. convert all letter to lowercase.
# 5. split it into a list of words using `.split()`.
# 6. count the length of this writing sample after removing the basic words.
# 7. print your conclusions: "The original word count is ____. After ___ basic words being removed, the current word count is ____." using f-strings or `.format{}`.
#
# The draft is here:
# ```python
# text = "There is interesting topic what young generation fun life more than older generation do. I think adolescent people enjoy life more than elder people do. I acknowledge this opinion.There is my grandfarther's example. In his case. He was enjoying his style of living when he was young because he had power, energy,curiousity,dream. He was always trying to do best for his ambition and was addicted to specific woman even though when it didn' t go well. He was feeling energy and fun.  However, he is not young anymore as you know. He has even serious disease now.This means that he doesn't have a lot of energy,dream. The all things he care is when he die. He told me before he was enjoyed his life a lot when he was young. Unfortunately it didn't last still now. There is curious topic that young generation have more fun in life.I have my grandfarther's case. Eventually, i agree this opinion. Actually, I am interested about opinion of other people who don't have experience same as me. I agree this statement even though it's not my experience.it's my grandfarther's case. So what do you think about this opinion?"
# ```
#
# **Tips:**
# - Using `.remove('is')` to remove the stop words from a list can only remove the first-occurance case. There are more than one `is` in this text. I will show you the `for` and `if` method in later session, but here, we can use the `replace(' is ' ,' ')`function on the text to replace the stop words with just spaces. This is equal to drop them from the text.
#
# - The function you can use `.lower()` , `replace()`, `split()`, `len()`

# %%
# Your code here
text = "There is interesting topic what young generation fun life more than older generation do. I think adolescent people enjoy life more than elder people do. I acknowledge this opinion.There is my grandfarther's example. In his case. He was enjoying his style of living when he was young because he had power, energy,curiousity,dream. He was always trying to do best for his ambition and was addicted to specific woman even though when it didn' t go well. He was feeling energy and fun.  However, he is not young anymore as you know. He has even serious disease now.This means that he doesn't have a lot of energy,dream. The all things he care is when he die. He told me before he was enjoyed his life a lot when he was young. Unfortunately it didn't last still now. There is curious topic that young generation have more fun in life.I have my grandfarther's case. Eventually, i agree this opinion. Actually, I am interested about opinion of other people who don't have experience same as me. I agree this statement even though it's not my experience.it's my grandfarther's case. So what do you think about this opinion?"
# 1
text_lst_original = text.split()

print(text_lst_original)

# 2
len_original = len(text_lst_original)
print(f"The original word-count is: {len_original}")
# Out:
# ['There', 'is', 'interesting', 'topic', 'what', 'young', 'generation', 'fun', 'life', 'more', 'than', 'older', 'generation', 'do.', 'I', 'think', 'adolescent', 'people', 'enjoy', 'life', 'more', 'than', 'elder', 'people', 'do.', 'I', 'acknowledge', 'this', 'opinion.There', 'is', 'my', "grandfarther's", 'example.', 'In', 'his', 'case.', 'He', 'was', 'enjoying', 'his', 'style', 'of', 'living', 'when', 'he', 'was', 'young', 'because', 'he', 'had', 'power,', 'energy,curiousity,dream.', 'He', 'was', 'always', 'trying', 'to', 'do', 'best', 'for', 'his', 'ambition', 'and', 'was', 'addicted', 'to', 'specific', 'woman', 'even', 'though', 'when', 'it', "didn'", 't', 'go', 'well.', 'He', 'was', 'feeling', 'energy', 'and', 'fun.', 'However,', 'he', 'is', 'not', 'young', 'anymore', 'as', 'you', 'know.', 'He', 'has', 'even', 'serious', 'disease', 'now.This', 'means', 'that', 'he', "doesn't", 'have', 'a', 'lot', 'of', 'energy,dream.', 'The', 'all', 'things', 'he', 'care', 'is', 'when', 'he', 'die.'
# ...

# %%
# 3: remove the stop words: is, and
text_cleaned = text.replace(' is ', ' ').replace(' and ', ' ')

# 4: to lower cases
text_cleaned = text_cleaned.lower()
text_cleaned
# Out:
# "there interesting topic what young generation fun life more than older generation do. i think adolescent people enjoy life more than elder people do. i acknowledge this opinion.there my grandfarther's example. in his case. he was enjoying his style of living when he was young because he had power, energy,curiousity,dream. he was always trying to do best for his ambition was addicted to specific woman even though when it didn' t go well. he was feeling energy fun.  however, he not young anymore as you know. he has even serious disease now.this means that he doesn't have a lot of energy,dream. the all things he care when he die. he told me before he was enjoyed his life a lot when he was young. unfortunately it didn't last still now. there curious topic that young generation have more fun in life.i have my grandfarther's case. eventually, i agree this opinion. actually, i am interested about opinion of other people who don't have experience same as me. i agree this statement even thou
# ...

# %%
# 5: split
text_lst_cleaned = text_cleaned.split()
text_lst_cleaned
# Out:
# ['there',
#  'interesting',
#  'topic',
#  'what',
#  'young',
#  'generation',
#  'fun',
#  'life',
#  'more',
#  'than',
#  'older',
#  'generation',
#  'do.',
#  'i',
#  'think',
#  'adolescent',
#  'people',
#  'enjoy',
#  'life',
#  'more',
#  'than',
#  'elder',
#  'people',
#  'do.',
#  'i',
#  'acknowledge',
#  'this',
#  'opinion.there',
#  'my',
#  "grandfarther's",
#  'example.',
#  'in',
#  'his',
#  'case.',
#  'he',
#  'was',
#  'enjoying',
#  'his',
#  'style',
#  'of',
#  'living',
#  'when',
#  'he',
#  'was',
#  'young',
#  'because',
#  'he',
#  'had',
#  'power,',
#  'energy,curiousity,dream.',
#  'he',
#  'was',
#  'always',
#  'trying',
#  'to',
#  'do',
#  'best',
#  'for',
#  'his',
#  'ambition',
#  'was',
#  'addicted',
#  'to',
#  'specific',
#  'woman',
#  'even',
#  'though',
#  'when',
#  'it',
#  "didn'",
#  't',
#  'go',
#  'well.',
#  'he',
#  'was',
#  'feeling',
#  'energy',
#  'fun.',
#  'however,',
#  'he',
#  'not',
#  'young',
#  'anymore',
# ...

# %%
# 6: count
len_cleaned = len(text_lst_cleaned)

# get the difference
len_diff = len_original - len_cleaned

# 7
print(f"The original word count is {len_original}. \nAfter {len_diff} basic words being removed, \nthe current word count is {len_cleaned}.")
# Out:
# The original word count is 194.
# After 7 basic words being removed, the current word count is 187.

# %% [markdown]
# ### 2.6 Tuples — like lists, but frozen
# A **tuple** is an *ordered, **immutable*** collection, written with `( )` (or just commas). Use tuples for
# fixed groupings that shouldn't change.

# %%
coffees = ('brazilian', 'costa_rican', 'colombian')
print(type(coffees), '| first:', coffees[0])

# parentheses are optional — commas make the tuple
# But I recommend adding the parentheses
grab_bag = 4, 'EHR', ['year', 'in', 'review']
print(grab_bag)

# coffees[0] = 'kenyan'    # TypeError: tuples are immutable
# Out:
# <class 'tuple'> | first: brazilian
# (4, 'EHR', ['year', 'in', 'review'])

# %% [markdown]
# ### 2.7 Sets — unique, unordered
# A **set** holds *unique*, *unordered* values in `{ }`. Great for de-duplicating and for fast membership tests
# with `in`. (Note: `{}` alone makes an empty **dict**, not a set — use `set()`.)

# %%
peanuts = {'snoopy', 'snoopy', 'woodstock'}
print(peanuts)                      # duplicates removed automatically
print('snoopy' in peanuts)          # membership test -> True

set1 = {'python', 'R'}
set2 = {'R', 'C++'}
print('union       :', set1.union(set2))           # everything
print('intersection:', set1.intersection(set2))    # in both
# Out:
# {'woodstock', 'snoopy'}
# True
# union       : {'python', 'C++', 'R'}
# intersection: {'R'}

# %% [markdown]
# ### 2.8 Dictionaries — key → value lookups
# A **dict** maps **keys** to **values** in `{key: value}`. It's the most important container for data work
# (think: column name → column, or id → record).

# %%
# define a dictionary
state_capital = {'Arizona': 'Phoenix',
                 'Colorado': 'Denver',
                 'New York': 'Albany'}

# get all keys
print(state_capital.keys())
# get all values
print(state_capital.values())
# get all KV pairs
print(state_capital.items())
# Out:
# dict_keys(['Arizona', 'Colorado', 'New York'])
# dict_values(['Phoenix', 'Denver', 'Albany'])
# dict_items([('Arizona', 'Phoenix'), ('Colorado', 'Denver'), ('New York', 'Albany')])

# %%
# retrieve the value for a key
print(state_capital['New York'])

# add new KV pair
state_capital['Texas'] = 'Austin'
print(state_capital)
# Out:
# Albany
# {'Arizona': 'Phoenix', 'Colorado': 'Denver', 'New York': 'Albany', 'Texas': 'Austin'}

# %% [markdown]
# In dictionary, the values can be any data types. Keys can only be the strings, int, float, and booleans. We usually use strings for the keys,

# %%
# a more complex dictionary
cryptos = {
    'Bitcoin': {
        'abbr.': 'BTC',
        'Born': '2009',
        'TotalAmount': '21 million',
        'HighestPrice': 126_198
    },
    'Ethereum': {
        'abbr.': 'ETH',
        'Born': '2015',
        'TotalAmount': 'Unlimited',
        'HighestPrice': 4_946
    }
}

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 5
# Your customer want to know the highest price of BTC is how many times of ETH‘s highest price. Can you do this by extracting the information from the dict above?

# %%
# your code here:
btc_hi = cryptos['Bitcoin']['HighestPrice']
eth_hi = cryptos['Ethereum']['HighestPrice']
btc_over_eth = round(btc_hi / eth_hi, 2)
print(f"Bitcoin's highest price is {btc_hi}, Ethereum's highest price is {eth_hi}, and the ratio of Bitcoin's highest price to Ethereum's highest price is {btc_over_eth}.")
# Out:
# Bitcoin's highest price is 126198, Ethereum's highest price is 4946, and the ratio of Bitcoin's highest price to Ethereum's highest price is 25.52.

# %% [markdown]
# #### ✏️ Try It Yourself — Exercise 6
# As a program director, you want to build student profiles in a organized way. Here are some basic student info, please create a dictionary to load all student info:
# - John is our youngest student at 21 years old. He has decided to focus his studies on Applied Statistics.
# - Jane is 22 years old and is pursuing a degree in Learning Analytics.
# - Jack, the most senior of the group at 25 years old, is our Measurement&Stats major.
#
# This should be a complex, nested dictionary with two-levels: the first level is specific student name, the second level is the basic info.

# %%
# Your code here
stu_profile = {"John": { "age": 21,
                        "program": "Applied Statistics"},
               "Jane": { "age": 22,
                        "program": "Leanring Analytics"},
               "Jack": { "age": 24,
                        "program": "Measurement&Stats"}
               }

# %% [markdown]
# ### 2.9 Ranges and type conversions
# **`range(start, stop, step)`** generates a sequence of integers (stop is *exclusive*) — most often used to drive
# loops. **Type conversions** use the type's name as a function: `int()`, `float()`, `str()`, `list()`.

# %%
# You need to use list() to convert a range variable into a list
num_seq = range(1,10,2)
print("The original range varaible's type is: ", type(num_seq))

num_seq = list(num_seq)
print("After conversion, you will have: ", num_seq)
# Out:
# The original range varaible's type is:  <class 'range'>
# After conversion, you will have:  [1, 3, 5, 7, 9]

# %% [markdown]
# ---
# ## 3. Conclusions & Key Takeaways
# - **Variables** name values; check types with `type()` / `isinstance()`.
# - **Scalars:** `bool`, `int`, `float`, `str`. **Containers:** `list`, `tuple`, `set`, `dict`, plus `range`.
# - **Mutable** (changeable in place): `list`, `set`, `dict`. **Immutable**: `int`, `float`, `bool`, `str`, `tuple`.
# - Strings and lists are **0-indexed** and support slicing `[start:stop]`; `stop` is exclusive.
# - Use **f-strings** (`f'{x}'`) for readable string building.
# - **Dicts** (key→value) and **lists** are the two containers you'll use most in data science.
# - Conversions can fail — e.g. `int('3.8')` errors; go `int(float('3.8'))` instead.
#
# ### 🧾 Quick Reference
# | Type | Example | Mutable? | Ordered? |
# |---|---|:--:|:--:|
# | `bool` | `True` | – | – |
# | `int` / `float` | `21` / `0.95` | no | – |
# | `str` | `'success'` | **no** | yes |
# | `list` | `['a', 5]` | **yes** | yes |
# | `tuple` | `('a', 5)` | no | yes |
# | `set` | `{'a', 'b'}` | yes | no |
# | `dict` | `{'k': 'v'}` | yes | yes (insertion) |
#
# ### 📖 An Online ALL-IN-ONE Syntax Quick Rerference
# [Click Me](https://cpan.ai/python-tools/)
#
# ### ⏭️ Coming Up Next
# **Session 03 — Operators, Input/Output, and NumPy.** We start computing with our data and meet NumPy arrays. Read McKinney Ch 4.
#
# ### 📌 This Week's Assignment
# Programming assignment 01 is posted on Canvas/GitHub.
# **Due 23:59, Sept.28.**
# Try every question yourself. Use AI in a responsible way. Submit it via Canvas.
#
# > 💡 **Tip:** make a copy in Colab (*File ▸ Save a copy in Drive*) and add your own notes — experimenting in the code cells is the fastest way to learn.
